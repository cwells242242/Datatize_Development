# %%
#Model Parameters
model = "gpt-4.0-mini"
temperature = 0.8
number_of_options = 1
max_tokens = 1000

# %%
#PROMPT CENTRAL ROUTING AGENT
prompt = """

*** SYSTEM ROLE CONTEXT ***
Your primary agent role is as the central section creating agent for future content generation. You will create a "table of contents" of sections of a larger process that will be used to guide further instructions generating agents.

*** DATA INPUTS CONTEXT ***
You will be passed in two key pieces of information, a user objective, and prior examples of user data. The user objective will be a high level goal that the user wants to achieve and is the overall objective for content generation. 
The prior examples of user data will be examples of how the user has previously achieved similar goals and will be the context basis for the creation of the output.

*** MAIN TASK ***
Follow the instructions below to create a table of contents of sections that will be used to guide further content generation
1. Analyze each prior example of user data and create a preliminary list of sections in a table of contents format that would be needed to achieve the user objective. Each section should have a title of 20 characters or less and a brief 2-3 sentences long description.
2. Synthesize the preliminary lists from each prior example into a single comprehensive list of sections.
3. Ensure that the final list of sections is logically ordered and covers all necessary aspects to achieve the user objective.
4. Call the section evaluation agent to review and refine the list of sections.
5. If the section evaluation agent suggests changes, incorporate those changes and restart the generation process from step 1.
6. If the section evaluation agent approves the list, finalize and reformat the table of contents in the specified JSON format.
7. Pass the finalized table of contents to the instruction_generation_agent for further content generation.

*** OUTPUT FORMAT INSTRUCTIONS ***
You are to return a JSON object with the following format:
{
    "output_type": "Identify whether the content should be generated as 'powerpoint', 'text document' or 'spreadsheet'",
    "table_of_contents": [
        {
            "section_title": "20 character or less title of section 1",
            "section_description": "2-3 sentence brief description of what section 1 will cover.",
            "parent section": "section title if a section should be nested under another section, if not applicable, put N/A"
        },
        {
            "section_title": "20 character or less title of section 2",
            "section_description": "2-3 sentence brief description of what section 2 will cover.",
            "parent section": "section title if a section should be nested under another section, if not applicable, put N/A"
        },
        ...
    ]
}    
"""

# %%
project_objective = "I want to create a create an SOW generator for new contracts"

# %%
example_1 = """
*** Example 1 ***
Statement of Work (SOW)

Project: Data Roadmap & AWS Infrastructure Modernization
Client: LogiTech
Consultant: ConsultingCo
Date: August 27, 2025
Duration: 6 Months
Total Cost: $1,000,000

Introduction

This Statement of Work (“SOW”) outlines the objectives, scope, deliverables, timeline, and financial terms for ConsultingCo’s engagement with LogiTech. The purpose of this engagement is to design and implement a comprehensive data modernization roadmap and migrate LogiTech’s existing infrastructure to Amazon Web Services (AWS).

ConsultingCo will leverage its expertise in cloud transformation, data architecture, and enterprise modernization to ensure LogiTech’s technology landscape is secure, scalable, and optimized for future growth.

Objectives

Assess LogiTech’s current data and infrastructure environment.

Develop a strategic data roadmap for modernization and cloud adoption.

Design and implement a secure, scalable AWS architecture.

Migrate legacy systems and data workloads to AWS.

Provide best practices for governance, compliance, and cost optimization.

Enable knowledge transfer and training for LogiTech teams.

Scope of Work
In-Scope

Current-State Assessment: Review existing infrastructure, data systems, and workloads.

Data Roadmap Development: Define modernization strategy, target architecture, and phased adoption plan.

AWS Cloud Architecture Design: Secure and scalable AWS environment setup (networking, storage, compute, security, IAM).

Migration Execution: Lift-and-shift and/or refactoring of prioritized applications and data workloads.

Governance & Cost Optimization: Implement tagging, monitoring, budgeting, and compliance frameworks.

Knowledge Transfer: Documentation and training sessions for LogiTech technical teams.

Out-of-Scope

Ongoing operational support post-migration (may be defined in a separate Managed Services agreement).

Non-AWS platform migrations.

Custom application development outside of agreed-upon refactoring requirements.

Deliverables

Discovery Report & Assessment Findings (Month 1)

Data Modernization Roadmap Document (Month 2)

AWS Architecture & Design Blueprint (Month 2)

Migration Plan & Prioritization Matrix (Month 3)

Execution of Migration Activities (Months 3–5)

Post-Migration Validation Report (Month 5)

Final Roadmap & Knowledge Transfer Package (Month 6)

Timeline

Project Start Date: August 27, 2025
Duration: 6 months

Phase	Duration	Key Milestones
Discovery & Assessment	1 Month	Discovery Report
Roadmap & Architecture	1 Month	Roadmap + Architecture Blueprint
Migration Planning	1 Month	Migration Plan
Migration Execution	2 Months	AWS Migration Complete
Validation & Knowledge Transfer	1 Month	Final Handoff

Roles & Responsibilities

ConsultingCo:

Lead assessment, strategy, design, and execution.

Provide AWS-certified consultants, architects, and engineers.

Deliver project management and governance.

LogiTech:

Provide access to existing systems and stakeholders.

Review and approve deliverables within agreed timelines.

Participate in workshops, training, and testing.

Financials

Total Cost: $1,000,000 (Fixed Fee)
Payment Terms:

20% upon project initiation (Month 1)

20% upon delivery of Roadmap & Architecture (Month 2)

30% upon completion of Migration Execution (Month 5)

30% upon final delivery & acceptance (Month 6)

Assumptions

LogiTech will provide necessary access to systems, data, and staff.

Any changes to scope will require a formal Change Order.

AWS consumption costs are not included in ConsultingCo’s fees.

Acceptance Criteria

Successful delivery of all listed deliverables.

Completion of agreed-upon migration with validation reports.

Approval from LogiTech stakeholders.

Signatures

For ConsultingCo
Name: ___________________________
Title: ___________________________
Date: ___________________________

For LogiTech
Name: ___________________________
Title: ___________________________
Date: ___________________________
"""

# %%
example_2 ="""
*** Example 2 ***

Statement of Work (SOW)

Project: Enterprise Data Dashboard & Analytics Enablement
Client: LogiTech
Consultant: ConsultingCo
Effective Date: August 27, 2025
Duration: 3 Months
Contract Value: $200,000

A. Project Purpose

LogiTech has identified the need to unify and visualize enterprise data in a single, interactive dashboard to support decision-making across departments. ConsultingCo will lead the design, mapping, and implementation of a modern data dashboard that consolidates disparate data sources, standardizes reporting, and delivers actionable insights to executives and operations teams.

B. Goals & Success Criteria

Integrate core operational, financial, and customer datasets into a unified data model.

Build a scalable dashboard platform with real-time or near-real-time reporting.

Deliver intuitive, role-based dashboards for executives and analysts.

Ensure user adoption through training and documentation.

Success will be measured by:

A fully functioning dashboard solution connected to at least 3 core data sources.

At least 5 executive-level KPIs defined, implemented, and validated.

Training of LogiTech staff with documented playbooks for ongoing maintenance.

C. Scope of Services
Included

Data Discovery & Mapping

Review existing data sources, quality, and ownership.

Define required transformations and business rules.

Data Model & Dashboard Design

Create centralized data schema.

Design dashboard wireframes and KPI definitions with LogiTech stakeholders.

Dashboard Development & Testing

Build dashboards in the agreed technology (e.g., Power BI, Tableau, or AWS QuickSight).

Perform user acceptance testing and refinements.

Knowledge Transfer

Provide documentation, admin guides, and training sessions.

Excluded

Ongoing managed services after project close.

Integration of non-priority systems not identified in discovery.

Advanced predictive analytics (may be scoped in a later phase).

D. Deliverables

Data Mapping Document – Complete inventory and transformation rules.

KPI Definition Workbook – List of prioritized KPIs and metrics.

Dashboard Wireframes – Approved design mockups.

Final Dashboard Implementation – Fully configured and tested dashboard solution.

Training & Documentation Package – User and admin guides plus training sessions.

E. Timeline & Milestones

Project Start Date: August 27, 2025
Project End Date: November 27, 2025

Month	Key Activities	Deliverables
Month 1	Data discovery, mapping, and KPI definition	Data Mapping Document, KPI Workbook
Month 2	Dashboard design and initial build	Dashboard Wireframes, Prototype
Month 3	Final development, UAT, training, and handoff	Final Dashboard, Documentation, Training
F. Roles & Responsibilities

ConsultingCo

Provide data architects, BI developers, and project manager.

Deliver designs, dashboards, and training materials.

LogiTech

Provide access to data sources and SMEs.

Participate in KPI definition workshops and UAT.

Approve deliverables within agreed timeframes.

G. Pricing & Payment Schedule

Total Fixed Fee: $200,000

Payment Milestones:

30% upon project initiation (Month 1)

40% upon delivery of prototype dashboards (Month 2)

30% upon final acceptance (Month 3)

H. Assumptions

LogiTech will provide timely access to data and resources.

Dashboard platform licensing is the responsibility of LogiTech.

Scope changes will be governed by a Change Request process.

I. Acceptance & Sign-Off

For ConsultingCo
Name: ______________________
Title: ______________________
Date: ______________________

For LogiTech
Name: ______________________
Title: ______________________
Date: ______________________
"""

# %%
example_3 = """
Statement of Work (SOW)

Project: Enterprise Data Analytics Support Program
Client: LogiTech
Consultant: ConsultingCo
Start Date: December 27, 2025
Duration: 12 Months
Contract Value: $250,000

1. Background & Purpose

LogiTech is undertaking a year-long effort to strengthen its data analytics capabilities to better inform strategic and operational decision-making. ConsultingCo will provide dedicated analyst resources to work alongside LogiTech’s internal teams, supporting ongoing reporting, analysis, and data-driven insights.

The engagement focuses on embedding ConsultingCo expertise within LogiTech’s business units to create repeatable analytics processes, scalable dashboards, and actionable reporting frameworks.

2. Engagement Overview

Length: 12 months (December 27, 2025 – December 26, 2026)

Resources: 2 full-time Data Analysts from ConsultingCo

Total Fee: $250,000 (fixed fee over the duration)

Delivery Approach: Hybrid of on-site collaboration and remote support

3. Objectives

Establish consistent reporting standards across departments.

Develop repeatable analysis models to support decision-making.

Deliver timely insights via dashboards and scheduled reports.

Train LogiTech stakeholders to self-serve insights.

Build an analytics knowledge base to support future scalability.

4. Scope of Services
ConsultingCo Responsibilities

Provide two dedicated data analysts for the duration of the project.

Perform data preparation, cleaning, modeling, and visualization.

Develop dashboards and recurring reporting solutions.

Facilitate quarterly workshops with LogiTech leadership.

Deliver documentation and training at project milestones.

LogiTech Responsibilities

Provide access to systems, databases, and SMEs.

Define reporting needs and KPI requirements.

Participate in workshops and review cycles.

Approve deliverables in a timely manner.

5. Deliverables

Standardized Reporting Templates (Month 2–3)

Operational Dashboard Suite (Month 4–6)

Quarterly Analytics Reports & Insights Decks (Q1–Q4)

End-of-Engagement Knowledge Base & Playbook (Month 12)

6. Milestones & Timeline
Quarter	Key Activities	Outputs
Q1 (Months 1–3)	Discovery, reporting templates, baseline dashboards	Reporting Templates, Initial Dashboard
Q2 (Months 4–6)	Expanded dashboards, first insights deck	Operational Dashboard Suite, Q2 Insights
Q3 (Months 7–9)	Advanced analysis, predictive models	Q3 Insights Deck
Q4 (Months 10–12)	Knowledge transfer, handoff playbook	Final Playbook, Q4 Insights, Closeout
7. Resourcing

Data Analyst 1 (Lead): Responsible for advanced modeling, dashboard design, and mentoring LogiTech staff.

Data Analyst 2 (Support): Responsible for reporting automation, data cleansing, and ongoing analysis.

Project Oversight: ConsultingCo Project Manager (part-time) ensures governance and milestone delivery.

8. Financials

Total Engagement Fee: $250,000 (fixed)

Payment Terms:

25% at project kickoff (December 2025)

25% at end of Q2 (June 2026)

25% at end of Q3 (September 2026)

25% upon final delivery & acceptance (December 2026)

9. Assumptions & Dependencies

LogiTech provides necessary system and data access before project start.

ConsultingCo analysts will work under LogiTech’s security and compliance guidelines.

Changes to scope will be managed via a Change Order.

Travel costs, if required, are billed separately with prior approval.

10. Acceptance & Authorization

For ConsultingCo
Name: ______________________
Title: ______________________
Date: ______________________

For LogiTech
Name: ______________________
Title: ______________________
Date: ______________________

"""

# %%
example_4 ="""
Statement of Work (SOW)

Project: Agentic AI Application – Customer-Facing Medical Chatbot
Client: LogiTech Medical Division
Consultant: ConsultingCo
Contract Value: $5,000,000
Engagement Duration: 10 Years
Resource Allocation: 15 Analysts (plus supporting architects & project leads)
Effective Start Date: August 27, 2025

The Project Outline:

This SOW defines the terms under which ConsultingCo will design, develop, and maintain a next-generation agentic AI application to power a customer-facing chatbot for LogiTech’s medical division. The chatbot will enhance patient engagement, provide accurate and compliant medical information, and streamline interactions between patients and providers while ensuring alignment with healthcare regulations (HIPAA, GDPR, and FDA guidance on AI in medical devices).

The Future of The Project:

The chatbot will serve as a trusted digital front door for patients, offering:

Symptom triage assistance

Appointment scheduling integration

Medication and treatment reminders

Insurance and billing inquiries

General medical education and FAQs

The vision is to create a scalable, AI-driven platform that evolves with advances in agentic AI and integrates seamlessly into LogiTech’s healthcare ecosystem over the next decade.

Key Objectives

Deliver a production-grade, HIPAA-compliant AI chatbot.

Establish agentic AI workflows for dynamic reasoning and contextual responses.

Integrate with patient portals, EHR systems, and call center platforms.

Ensure scalability, monitoring, and continuous improvement over 10 years.

Provide ongoing enhancements aligned with regulatory and technological advances.

Items Within The Project Scope
In-Scope

AI chatbot application development (MVP to enterprise scale).

Data ingestion pipelines for structured/unstructured healthcare data.

Compliance frameworks for patient privacy and safety.

Integration with LogiTech’s medical IT systems.

Continuous monitoring, retraining, and fine-tuning of AI models.

Multi-language and accessibility support.

Out-of-Scope

Clinical decision-making beyond approved protocols.

Integration with third-party systems not identified at project initiation.

Patient care responsibilities (the chatbot is advisory, not diagnostic).

Key Deliverables & Technologies

Year 1: MVP chatbot, HIPAA-compliant architecture, pilot deployment.

Year 2–3: Full production rollout with EHR/portal integrations.

Year 4–6: Expansion into advanced features (voice assistants, multi-lingual).

Year 7–9: AI model upgrades, agent orchestration improvements.

Year 10: Final modernization roadmap & transition plan.

Supporting deliverables: technical documentation, compliance reports, monitoring dashboards, quarterly insights reports, and user training modules.

Timeline & Milestones
Year	Milestones	Key Outputs
1	Discovery, architecture, MVP pilot	Initial chatbot live
2–3	Production rollout	Chatbot integrated into patient systems
4–6	Feature expansion	Voice + multi-language
7–9	AI advancements	Next-gen agentic models
10	Transition & modernization	Final roadmap

Governance & Oversight

Steering Committee: Bi-annual reviews with LogiTech executives.

Project Management Office (PMO): Quarterly delivery checkpoints.

Compliance Board: Ongoing validation with medical/legal advisors.

The Team That Can Deliver

15 Analysts: Data analysis, reporting, dashboarding, patient experience analytics.

AI/ML Engineers: Model development, fine-tuning, monitoring.

Cloud Architects: Infrastructure setup on AWS HIPAA-eligible services.

Compliance Officers: Regulatory oversight.

Project Leads: Ensure delivery and stakeholder alignment.

Project Costs:

Total Engagement Fee: $5,000,000 (fixed, spread over 10 years).

Payment Schedule:

10% at project kickoff.

15% at Year 1 MVP delivery.

20% at full production rollout (Year 3).

20% across Years 4–6 deliverables.

20% across Years 7–9 deliverables.

15% at final Year 10 transition and roadmap delivery.

Technical Approach

Agentic AI Architecture: Leveraging reasoning agents with tool orchestration.

Data Security: HIPAA-compliant encryption, audit logging, role-based access.

Cloud Infrastructure: AWS (Amazon Bedrock, SageMaker, Comprehend Medical).

Monitoring: Continuous monitoring with dashboards for accuracy, drift, and compliance.

Human-in-the-Loop (HITL): Escalation to human agents for edge cases.

Risk Management

Regulatory Risk: Addressed via compliance officers and quarterly audits.

AI Bias & Accuracy Risk: Mitigated with diverse training data, monitoring, and bias testing.

Operational Risk: Redundant cloud infrastructure, DR plans.

Adoption Risk: Mitigated with change management and training programs.

Compliance & Regulatory Framework

HIPAA, GDPR, CCPA compliance.

FDA emerging guidance on AI/ML-based SaMD (Software as a Medical Device).

Data residency requirements depending on region.

Annual compliance certification audits.

Training & Knowledge Transfer

Quarterly training sessions for internal LogiTech staff.

Documentation for chatbot operations, data pipelines, and retraining workflows.

User adoption workshops for non-technical staff.

Support & Maintenance

24/7 monitoring and support SLAs.

Continuous updates for new regulations and AI advancements.

Performance optimization reviews every 6 months.

End-of-year “innovation sprints” to incorporate emerging AI features.

Assumptions & Dependencies

LogiTech will provide timely access to EHR systems, APIs, and SMEs.

AWS cloud services licensing is procured separately by LogiTech.

Scope changes require mutual agreement via a Change Order.

Medical chatbot will be advisory only, not diagnostic or prescriptive.

Acceptance Criteria

MVP chatbot deployed by end of Year 1.

Successful EHR integration with secure data handling.

Accuracy rate of ≥90% on approved knowledge base queries.

Annual compliance certification passed.

Final acceptance upon delivery of Year 10 modernization roadmap.

Termination & Renewal

Either party may terminate with 90 days’ notice for material breach.

Renewal options available for ongoing managed services beyond 10 years.

Signatures

For ConsultingCo
Name: ______________________
Title: ______________________
Date: ______________________

For LogiTech Medical
Name: ______________________
Title: ______________________
Date: ______________________

"""

# %%
from openai import OpenAI

client = OpenAI(
  api_key="OPENAI_API_Key"
)

completion = client.chat.completions.create(
  model="gpt-4o-mini",
  store=True,
  messages=[
    {
      "role": "user", 
      "content": 
        f"""
          {prompt} 
          {project_objective}
          {example_1}
          {example_2}
          {example_3}
          {example_4}
        """

    }
  ],
  n=number_of_options,
  temperature=temperature,
  max_tokens=max_tokens
)

print(completion.choices[0].message.content)
# Out:
# {
#     "output_type": "text document",
#     "table_of_contents": [
#         {
#             "section_title": "Introduction",
#             "section_description": "This section provides an overview of the Statement of Work (SOW), including the purpose, goals, and context of the project. It sets the stage for the specific objectives and scope of the engagement.",
#             "parent section": "N/A"
#         },
#         {
#             "section_title": "Objectives",
#             "section_description": "Outline the key objectives of the project, detailing the desired outcomes and expectations for both the consultant and the client. This section should highlight what success looks like for the engagement.",
#             "parent section": "N/A"
#         },
#         {
#             "section_title": "Scope of Work",
# ...

# %%
{
    "output_type": "text document",
    "table_of_contents": [
        {
            "section_title": "Introduction",
            "section_description": "This section will provide an overview of the Statement of Work (SOW) generator, its purpose, and how it will facilitate the creation of SOW documents tailored for various projects.",
            "parent section": "N/A"
        },
        {
            "section_title": "Objectives",
            "section_description": "Outlines the key objectives for the SOW generator, including ensuring clarity of scope, deliverables, timelines, and pricing structures tailored to client needs.",
            "parent section": "N/A"
        },
        {
            "section_title": "Project Scope",
            "section_description": "Details the in-scope and out-of-scope items for projects, helping users define the boundaries and expectations for the engagement clearly.",
            "parent section": "N/A"
        },
        {
            "section_title": "Deliverables",
            "section_description": "Lists expected deliverables for the project, including formats and timelines to ensure all parties are aligned on what will be produced.",
            "parent section": "N/A"
        },
        {
            "section_title": "Timeline & Milestones",
            "section_description": "This section will outline the project timeline and key milestones to track progress, ensuring timely completion of deliverables.",
            "parent section": "N/A"
        },
        {
            "section_title": "Roles & Responsibilities",
            "section_description": "Defines the roles and responsibilities of both the consultant and client, ensuring accountability and clarity in the project execution.",
            "parent section": "N/A"
        },
        {
            "section_title": "Financials",
            "section_description": "Provides details on the financial aspects of the project, including the total cost, payment terms, and any other financial arrangements.",
            "parent section": "N/A"
        },
        {
            "section_title": "Assumptions",
            "section_description": "Lists any assumptions made during the creation of the SOW, which can impact the project scope and execution, ensuring mutual understanding.",
            "parent section": "N/A"
        },
        {
            "section_title": "Acceptance Criteria",
            "section_description": "Details the criteria that must be met for project deliverables to be accepted by the client, ensuring clear expectations on outcomes.",
            "parent section": "N/A"
        },
        {
            "section_title": "Signatures",
            "section_description": "Provides space for signatures from both parties to formalize the agreement, ensuring both sides acknowledge and accept the terms of the SOW.",
            "parent section": "N/A"
        }
    ]
}
# Out:
# {'output_type': 'text document',
#  'table_of_contents': [{'section_title': 'Introduction',
#    'section_description': 'This section will provide an overview of the Statement of Work (SOW) generator, its purpose, and how it will facilitate the creation of SOW documents tailored for various projects.',
#    'parent section': 'N/A'},
#   {'section_title': 'Objectives',
#    'section_description': 'Outlines the key objectives for the SOW generator, including ensuring clarity of scope, deliverables, timelines, and pricing structures tailored to client needs.',
#    'parent section': 'N/A'},
#   {'section_title': 'Project Scope',
#    'section_description': 'Details the in-scope and out-of-scope items for projects, helping users define the boundaries and expectations for the engagement clearly.',
#    'parent section': 'N/A'},
#   {'section_title': 'Deliverables',
# ...
